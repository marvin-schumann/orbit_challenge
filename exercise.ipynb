# %% [markdown]
# # PDF Processing via LLMaaS

# %% [markdown]
# ## 0. Setting your Name and Email
#
# Please starting by putting your name and email in the following variables - please stick to the required format i.e. NAME_SURNAME

# %%
# WRITE YOUR NAME_SURNAME HERE, AS WELL AS YOUR EMAIL WITH WHICH YOU LOGGED IN INTO CELONIS
MY_NAME = 'AHMED_AYADI'
MY_EMAIL = 'a.ayadi@celonis.de'

# %% [markdown]
# ## 1. Installing and importing required packages

# %%
#Run the first time you execute the script and then comment it out again.
#%pip install -r requirements.txt

# %% [markdown]
# ## 2. Extract information from Invoices

# %% [markdown]
# This is the section you will need to fill in. Your code should create the following
# - **a pandas dataframe called df that includes the extracted information**.
# - **the dataframe should contain a column called 'po_reference' that contains the reference to the PO**
# - **the values in the column 'po_reference' should be a 11-char long strings. Use left padding with zeros where needed.**

# %%
# ADD YOUR CODE HERE
# %run solution.ipynb
# Out:
# Current Directory: /home/jovyan/Orbit Challenge
# Python Verison: 0.1.2
#   0%|          | 0/3 [00:00<?, ?it/s]
# Filename: INV-2021-002.png
#  33%|███▎      | 1/3 [00:03<00:06,  3.36s/it]
# Filename: INV-2020-001.png
#  67%|██████▋   | 2/3 [00:06<00:03,  3.21s/it]
# Filename: INV-2021-001.png
# 100%|██████████| 3/3 [00:09<00:00,  3.29s/it]
# File: Invoices/INV-2020-07-001853.pdf | # Pages: 1
# File: Invoices/INV-2020-08-001247.pdf | # Pages: 1
#   0%|          | 0/2 [00:00<?, ?it/s]
# Filename: INV-2020-07-001853.pdf
#  50%|█████     | 1/2 [00:02<00:02,  2.33s/it]
# Filename: INV-2020-08-001247.pdf
# 100%|██████████| 2/2 [00:03<00:00,  1.96s/it]
# File deleted.

# %% [markdown]
# ## 3. Pushing Data back to Data Pool

# %%
# %run push.ipynb
# Out:
# [2025-07-22 17:36:56,790] INFO: No `base_url` given. Using environment variable 'CELONIS_URL'
# [2025-07-22 17:36:56,829] WARNING: Your PyCelonis Version 2.12.0 is outdated (Newest Version: 2.14.0). Please upgrade the package via: pip install --extra-index-url=https://pypi.celonis.cloud/ pycelonis pycelonis_core --upgrade
# [2025-07-22 17:36:56,963] WARNING: KeyType is not set. Defaulted to 'APP_KEY'.
# [2025-07-22 17:36:56,982] INFO: Initial connect successful! PyCelonis Version: 2.12.0
# [2025-07-22 17:36:57,708] INFO: Successfully created data push job with id '461b3f56-2b0b-4fc5-92ed-24a819a9a220'
# [2025-07-22 17:36:57,709] INFO: Add data frame as file chunks to data push job with id '461b3f56-2b0b-4fc5-92ed-24a819a9a220'
#   0%|          | 0/1 [00:00<?, ?it/s]
# [2025-07-22 17:36:57,857] INFO: Successfully upserted file chunk to data push job with id '461b3f56-2b0b-4fc5-92ed-24a819a9a220'
# [2025-07-22 17:36:58,250] INFO: Successfully triggered execution for data push job with id '461b3f56-2b0b-4fc5-92ed-24a819a9a220'
# [2025-07-22 17:36:58,251] INFO: Wait for execution of data push job with id '461b3f56-2b0b-4fc5-92ed-24a819a9a220'
# 0it [00:00, ?it/s]
# [2025-07-22 17:37:06,385] INFO: Successfully created table 'DOC_EXTRACTION_AHMED_AYADI' in data pool
# [2025-07-22 17:37:06,500] INFO: Successfully deleted data push job with id '461b3f56-2b0b-4fc5-92ed-24a819a9a220'
# Created table  DOC_EXTRACTION_AHMED_AYADI
# Data model duplicated
# Data model renamed to Challenge_Procurement_AHMED_AYADI
# [2025-07-22 17:37:07,626] INFO: Successfully added data model table with id '26238e2f-b137-4ed5-9159-94dd5ee93b35' to data model
# Table 'DOC_EXTRACTION_AHMED_AYADI' added to Data Model.
# Creating FK from 'CASE_TABLE' (ID: 8e84fe85-469d-4712-a064-2d041b9d4232) to 'DOC_EXTRACTION_AHMED_AYADI' (ID: 26238e2f-b137-4ed5-9159-94dd5ee93b35) on columns: [('_CASE_KEY', 'po_reference')]
# [2025-07-22 17:37:07,772] INFO: Successfully created foreign key with id '886a077a-9a4b-4eab-bf32-81a5d3fb57dd'
# Successfully created FK: 886a077a-9a4b-4eab-bf32-81a5d3fb57dd
# Found member with email: a.ayadi@celonis.de
# Gave permissions to Challenge_Procurement_AHMED_AYADI to member with email: a.ayadi@celonis.de
# [2025-07-22 17:37:08,323] INFO: Successfully triggered data model reload for data model with id 'c4b702fd-d536-4c2b-87e8-9cf17a170e65'
# [2025-07-22 17:37:08,324] INFO: Wait for execution of data model reload for data model with id 'c4b702fd-d536-4c2b-87e8-9cf17a170e65'
# 0it [00:00, ?it/s]
